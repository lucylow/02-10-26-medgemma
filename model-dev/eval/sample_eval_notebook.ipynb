# %% [markdown]
# # Sample evaluation notebook (model-dev)
#
# Purpose: Run eval_metrics and bias_audit on a small dev set; visualize subgroup metrics.
#
# Usage: Open in Jupyter, set `EVAL_DATASET_PATH` and run cells.

# %%
import sys
sys.path.insert(0, 'model-dev')
from eval.eval_metrics import compute_nlg_metrics, compute_clinical_metrics
from eval.bias_audit import run_bias_audit

# Example: synthetic preds/refs
preds = ["Summary A", "Summary B"]
refs = ["Reference A", "Reference B"]
print(compute_nlg_metrics(preds, refs))
